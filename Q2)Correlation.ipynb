# %%
from common_imports import *

# %%
data_df = pd.read_csv('/Applications/Kaushik/North Texas/Education/Semester 5, Fall 2024/Project/Workspace/CSV/cleaned_dataset.csv')

df = data_df

print(df.head())
# Out:
#       Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0  PAYMENT                         5                              2
# 1  PAYMENT                         6                              2
# 2  PAYMENT                         2                              2
# 3  PAYMENT                         3                              2
# 4  PAYMENT                         5                              2
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0         -30.750000          115.180000     Late delivery
# 1          33.599998           96.000000     Late delivery
# 2          24.690001           75.980003  Shipping on time
# 3           9.100000           91.000000     Late delivery
# 4         -21.750000           87.000000     Late delivery
#
#    Late_delivery_risk  Category Id    Category Name Customer City  ...  \
# 0                   1           17           Cleats       Bayamon  ...
# ...

# %% [markdown]
# Data Cleaning:

# %%
#These are the columns which were dropped

#df = df.drop('Product Image', axis=1)

#df = df.drop('Type', axis=1)

#df = df.drop('Customer City', axis=1)

#df = df.drop('Customer Country', axis=1)

#df = df.drop(['Customer Email','Customer Fname','Customer Lname','Department Name','Order Region'], axis=1)

df = df.drop(['Order Item Cardprod Id','Product Card Id','Product Category Id','Category Id','Order Item Quantity','order date (DateOrders)',
              'shipping date (DateOrders)','Order Id','Order Item Id','Order Customer Id'],axis=1)

df = df.drop(['Latitude','Delivery Status','Days for shipping (real)','Order Zipcode','Customer State','Order Status','Longitude',
              'Product Name'],axis=1)

df = df.drop(['Customer Segment','Late_delivery_risk','Order City','Order State','Market','Customer Password','Product Status'],axis=1)

df = df.drop('Category Name', axis=1)

df = df.drop('Shipping Mode', axis = 1)
  
df = df.drop(['Days for shipment (scheduled)','Customer Zipcode','Customer Street'], axis=1)

print(df.head())
# Out:
#    Benefit per order  Sales per customer Customer Email Customer Fname  \
# 0         -30.750000          115.180000      XXXXXXXXX           Mary
# 1          33.599998           96.000000      XXXXXXXXX      Elizabeth
# 2          24.690001           75.980003      XXXXXXXXX      Katherine
# 3           9.100000           91.000000      XXXXXXXXX           Mary
# 4         -21.750000           87.000000      XXXXXXXXX         Dennis
#
#    Customer Id Customer Lname  Department Id Department Name Order Country  \
# 0         9083          Frank              4         Apparel         India
# 1          639        Pittman              5            Golf     Australia
# 2         9702          Tyler              5            Golf       Turquía
# 3         9114          Smith              5            Golf      Mongolia
# 4         1362          Smith              5            Golf       Turquía
#
#    Order Item Discount  Order Item Discount Rate  Order Item Product Price  \
# ...

# %%
df = df.drop(['Customer Fname','Customer Lname','Department Name','Order Region'], axis=1)

# %%
df = df.drop('Customer Email', axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
label_encoder = LabelEncoder()


#df['Customer Country'] = label_encoder.fit_transform(df['Customer Country'])


df['Order Country'] = label_encoder.fit_transform(df['Order Country'])

# %%
df = df.drop('Category Name', axis = 1)

# %%
correlation_matrix = df.corr()

# Visualize correlation with a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# Focus on correlations with 'Benefit per order'
correlation_with_benefit = correlation_matrix['Benefit per order'].sort_values(ascending=False)
print(correlation_with_benefit)
# Out:
# Benefit per order           1.000000
# Order Profit Per Order      1.000000
# Order Item Profit Ratio     0.794947
# Sales per customer          0.485544
# Order Item Total            0.485544
# Sales                       0.479312
# Order Item Product Price    0.362107
# Product Price               0.362107
# Order Item Discount         0.198221
# Department Id               0.136044
# Customer Id                 0.008217
# Order Country               0.001969
# Order Item Discount Rate   -0.087608
# Name: Benefit per order, dtype: float64
